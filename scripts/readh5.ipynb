# %%
import h5py
import numpy as np
import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
inputfile = h5py.File("/global/cfs/cdirs/m3246/twamorka/omnifold_atlas/LorentzGroupNetwork/data/toptag/conversion/raw2h5/utils/condor/pd_chunk_1_c_14082024.h5", "r")

# %%
inputfile.keys()
# Out:
# <KeysViewHDF5 ['Nobj', 'Pmu', 'is_signal', 'jet_pt', 'label', 'mass', 'truth_Pmu']>

# %%
# Nobj = inputfile['Nobj']

# %%
# np.array(Nobj)

# %%
Pmu = inputfile['Pmu']
# np.array(Pmu)[0]

# %%
np.array(Pmu)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 np.array(Pmu)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/.conda/envs/zjets/lib/python3.11/site-packages/h5py/_hl/dataset.py:1063, in Dataset.__array__(self, dtype)
#    1060 if self.size == 0:
#    1061     return arr
# -> 1063 self.read_direct(arr)
#    1064 return arr
#
# File ~/.conda/envs/zjets/lib/python3.11/site-packages/h5py/_hl/dataset.py:1024, in Dataset.read_direct(self, dest, source_sel, dest_sel)
#    1021     dest_sel = sel.select(dest.shape, dest_sel)
#    1023 for mspace in dest_sel.broadcast(source_sel.array_shape):
# -> 1024     self.id.read(mspace, fspace, dest, dxpl=self._dxpl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# ...
